# %%
# Import Libraries
import serial
import numpy as np
import time
import os

# %%
import serial.tools.list_ports

# %%
ports = serial.tools.list_ports.comports()

for port in ports:
    if port.serial_number == "551313238373517030C1":
        arduino_port = port.device
    elif port.serial_number == "AB0LUSK7":
        balance_port = port.device

# %%
import pellet_sorter as ps

# %%
### Initializations
# sorter_chain, sorter_parameters and arduino should be global variables

n_joints = 2
sorter_parameters = [{'steps_in_rotation':0,'gear_ratio':0,'length_mm':0,'bound_rad':0, 'cartesian':[0,0]} for k in range(n_joints)]
## Top
sorter_parameters[0]['steps_in_rotation'] = np.round(200*1.1)   # Calibrate multiplicative factor to compensate lost steps if necessary
sorter_parameters[0]['gear_ratio'] = 6
sorter_parameters[0]['length_mm'] = 180.5
sorter_parameters[0]['bound_rad'] = np.deg2rad(35)    # np.deg2rad(35)  # IK Rotation bound in either direction, not total
sorter_parameters[0]['cartesian'] = [sorter_parameters[0].get('length_mm'), 0]
## Bot
sorter_parameters[1]['steps_in_rotation'] = 812
sorter_parameters[1]['gear_ratio'] = 2.4
sorter_parameters[1]['length_mm'] = np.sqrt(32.7**2 + 79.2**2)  # 84.4
sorter_parameters[1]['bound_rad'] = np.deg2rad(10*360)
sorter_parameters[1]['cartesian'] = [sorter_parameters[1].get('length_mm'), 0]


sorter_chain = ps.sorter_chain_update(sorter_parameters)

tray_1 = ps.Tray('1', [sorter_parameters[0]['length_mm'], 0], [
    ps.Slot([79.2,32.7]),
    ps.Slot([32.7,79.2]),
    ps.Slot([-32.7,79.2]),
    ps.Slot([-79.2,32.7]),
    ps.Slot([-79.2,-32.7]),
    ps.Slot([-32.7,-79.2]),
    ps.Slot([32.7,-79.2]),
    ps.Slot([79.2,-32.7]),
    ps.Slot([0,0]), 
    ])

tray_1.fill_all_slots_ez(0, 0.160)  # Adjust cup capacity in kg here

tray_1.set_all_material('PLA####')
# Out:
# /home/miguel/.local/lib/python3.10/site-packages/ikpy/chain.py:60: UserWarning: Link Base link (index: 0) is of type 'fixed' but set as active in the active_links_mask. In practice, this fixed link doesn't provide any transformation so is as it were inactive
#   warnings.warn("Link {} (index: {}) is of type 'fixed' but set as active in the active_links_mask. In practice, this fixed link doesn't provide any transformation so is as it were inactive".format(link.name, link_index))

# %%
os.system("/home/miguel/Downloads/arduino-cli_0.33.0_Linux_64bit/arduino-cli compile --fqbn arduino:avr:uno ../../Arduino/Pellet_sorter_v2/Pellet_sorter_v2.ino")
# Out:
# Sketch uses 9908 bytes (30%) of program storage space. Maximum is 32256 bytes.
# Global variables use 513 bytes (25%) of dynamic memory, leaving 1535 bytes for local variables. Maximum is 2048 bytes.
#
# Used library Version Path
# AccelStepper 1.64    /home/miguel/Arduino/libraries/AccelStepper
#
# Used platform Version Path
# arduino:avr   1.8.6   /home/miguel/.arduino15/packages/arduino/hardware/avr/1.8.6
# 0

# %%
### Serial initialization
## Arduino
arduino = serial.Serial(arduino_port, 9600)
os.system("/home/miguel/Downloads/arduino-cli_0.33.0_Linux_64bit/arduino-cli compile --fqbn arduino:avr:uno ../../Arduino/Pellet_sorter_v2/Pellet_sorter_v2.ino")
os.system("/home/miguel/Downloads/arduino-cli_0.33.0_Linux_64bit/arduino-cli upload -p "+arduino_port+" --fqbn arduino:avr:uno ../../Arduino/Pellet_sorter_v2/Pellet_sorter_v2.ino")
# Out:
# Sketch uses 9908 bytes (30%) of program storage space. Maximum is 32256 bytes.
# Global variables use 513 bytes (25%) of dynamic memory, leaving 1535 bytes for local variables. Maximum is 2048 bytes.
#
# Used library Version Path
# AccelStepper 1.64    /home/miguel/Arduino/libraries/AccelStepper
#
# Used platform Version Path
# arduino:avr   1.8.6   /home/miguel/.arduino15/packages/arduino/hardware/avr/1.8.6
# 0

# %%
arduino.write('v0'.encode("utf-8"))
# Out:
# 2

# %%
## Balance
balance = serial.Serial(balance_port, 9600)

# %%
### MAIN SCRIPT
ps.fill_tray(tray_1, [sum([sorter_parameters[n].get('length_mm') for n in range(len(sorter_parameters))]), 0], sorter_parameters, sorter_chain, arduino, balance)
# Out:
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 0.818  kg
# AUNG/W+ 1.458  kg
# ASNG/W+ 1.506  kg
# Closing valve
# val finished
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 0.228  kg
# AUNG/W+ 1.166  kg
# ASNG/W+ 1.324  kg
# Closing valve
# val finished
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 1.814  kg
# AUNG/W+ 2.062  kg
# ASNG/W+ 2.072  kg
# Closing valve
# val finished
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 1.540  kg
# AUNG/W+ 1.720  kg
# AUNG/W+ 1.714  kg
# AUNG/W+ 1.686  kg
# ASNG/W+ 1.742  kg
# Closing valve
# val finished
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 1.106  kg
# ASNG/W+ 1.446  kg
# Closing valve
# val finished
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 0.000  kg
# AUNG/W+ 1.436  kg
# ASNG/W+ 1.802  kg
# Closing valve
# val finished
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 0.004  kg
# AUNG/W+ 1.252  kg
# AUNG/W+ 1.446  kg
# AUNG/W+ 1.474  kg
# ASNG/W+ 1.464  kg
# Closing valve
# val finished
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 1.186  kg
# ASNG/W+ 1.288  kg
# Closing valve
# val finished
# pos finished
# Opening valve
# val finished
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# ASNG/W+ 0.000  kg
# AUNG/W+ 0.028  kg
# AUNG/W+ 2.378  kg
# ASNG/W+ 2.892  kg
# Closing valve
# val finished
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 ### MAIN SCRIPT
# ----> 2 ps.fill_tray(tray_1, [sum([sorter_parameters[n].get('length_mm') for n in range(len(sorter_parameters))]), 0], sorter_parameters, sorter_chain, arduino, balance)
#
# File ~/Pellet_sorter/Code/Python/Pellet_sorter_py/pellet_sorter.py:380, in fill_tray(tray, cartesian_initial, sorter_parameters, sorter_chain, arduino, balance)
#     378 IK_plot(cartesian_initial, cartesian_prev, sorter_parameters, sorter_chain)
#     379 goToCartesianFrom(cartesian_initial, cartesian_prev, sorter_parameters, sorter_chain, arduino)
# --> 380 waitForSerialStr("pos finished")
#
# TypeError: waitForSerialStr() missing 1 required positional argument: 'arduino'
